# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
link = "https://en.wikipedia.org/wiki/List_of_American_films_of_2018"
df1 = pd.read_html(link)[2]
df2 = pd.read_html(link, header=0)[3]
df3 = pd.read_html(link, header=0)[4]
df4 = pd.read_html(link, header=0)[5]

# %%
df1
# Out:
#     Opening  Opening.1                                Title  \
# 0   JANUARY          5              Insidious: The Last Key
# 1   JANUARY          5                     The Strange Ones
# 2   JANUARY          5                             Stratton
# 3   JANUARY         10                        Sweet Country
# 4   JANUARY         12                         The Commuter
# ..      ...        ...                                  ...
# 69    MARCH         29                     Ready Player One
# 70    MARCH         30               Tyler Perry's Acrimony
# 71    MARCH         30  God's Not Dead: A Light in Darkness
# 72    MARCH         30                               Gemini
# 73    MARCH         30                  The Last Movie Star
#
#                                    Production company  \
# 0   Universal Pictures / Blumhouse Productions / S...
# 1                              Vertical Entertainment
# 2                                   Momentum Pictures
# ...

# %%
df = df1.append(df2.append(df3.append(df4,ignore_index=True),ignore_index=True),ignore_index=True)

# %%
df
# Out:
#       Opening  Opening.1                       Title  \
# 0     JANUARY          5     Insidious: The Last Key
# 1     JANUARY          5            The Strange Ones
# 2     JANUARY          5                    Stratton
# 3     JANUARY         10               Sweet Country
# 4     JANUARY         12                The Commuter
# ..        ...        ...                         ...
# 264  DECEMBER         25             Holmes & Watson
# 265  DECEMBER         25                        Vice
# 266  DECEMBER         25         On the Basis of Sex
# 267  DECEMBER         25                   Destroyer
# 268  DECEMBER         28  Black Mirror: Bandersnatch
#
#                                     Production company  \
# 0    Universal Pictures / Blumhouse Productions / S...
# 1                               Vertical Entertainment
# 2                                    Momentum Pictures
# 3                                 Samuel Goldwyn Films
# ...

# %%
pip install tmdbv3api
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from tmdbv3api import TMDb
import json
import requests
tmdb = TMDb()
tmdb.api_key = '76daa7075f7dc2e4a339f93d8f71288d'

# %%
from tmdbv3api import Movie
tmdb_movie = Movie()
def get_genre(x):
    genres = []
    result = tmdb_movie.search(x)
    movie_id = result[0].id
    response = requests.get('https://api.themoviedb.org/3/movie/{}?api_key={}'.format(movie_id,tmdb.api_key))
    data_json = response.json()
    if data_json['genres']:
        genre_str = " " 
        for i in range(0,len(data_json['genres'])):
            genres.append(data_json['genres'][i]['name'])
        return genre_str.join(genres)
    else:
        np.NaN

# %%
get_genre(str(df['Title'][0]))
# Out:
# 'Horror Mystery Thriller'

# %%
df['genres'] = df['Title'].map(lambda x: get_genre(str(x)))

# %%
df = df[['Title','Cast and crew','genres']]

# %%
df.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  Insidious: The Last Key  Adam Robitel (director); Leigh Whannell (scree...
# 1         The Strange Ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 Stratton  Simon West (director); Duncan Falconer, Warren...
# 3            Sweet Country  Warwick Thornton (director); David Tranter, St...
# 4             The Commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres
# 0  Horror Mystery Thriller
# 1           Thriller Drama
# 2          Action Thriller
# 3    Drama History Western
# 4          Action Thriller

# %%
df['Cast and crew'][0]
# Out:
# 'Adam Robitel (director); Leigh Whannell (screenplay); Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Kirk Acevedo, Bruce Davison'

# %%
df['Cast and crew'][0].split("(director)")[0].strip()
# Out:
# 'Adam Robitel'

# %%
def drget(x):
    if "(director)" in x:
        return x.split("(director)")[0].strip()
    elif "(director/screenplay)" in x:
        return x.split("(director/screenplay)")[0].strip()
    else:
        return x.split(" (director/screenplay)")[0].strip()

# %%
df["director_name"] = df['Cast and crew'].map(lambda x : drget(x))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df["director_name"]
# Out:
# 0            Adam Robitel
# 1        Lauren Wolkstein
# 2              Simon West
# 3        Warwick Thornton
# 4      Jaume Collet-Serra
#               ...
# 264            Etan Cohen
# 265            Adam McKay
# 266            Mimi Leder
# 267          Karyn Kusama
# 268           David Slade
# Name: director_name, Length: 269, dtype: object

# %%
df['Cast and crew'][0].replace(";",",").split(",")
# Out:
# ['Adam Robitel (director)',
#  ' Leigh Whannell (screenplay)',
#  ' Lin Shaye',
#  ' Angus Sampson',
#  ' Leigh Whannell',
#  ' Spencer Locke',
#  ' Caitlin Gerard',
#  ' Kirk Acevedo',
#  ' Bruce Davison']

# %%
df['Cast and crew'][0].split("(screenplay);")
# Out:
# ['Adam Robitel (director); Leigh Whannell ',
#  ' Lin Shaye, Angus Sampson, Leigh Whannell, Spencer Locke, Caitlin Gerard, Kirk Acevedo, Bruce Davison']

# %%
def screenplaying(x):
    c = 0
    if "(screenplay)" in x:
        c+=1
    elif "(co-director/screenplay)" in x:
        c+=1
    elif "(director/screenplay)":
        c+=1
    return c

# %%
df['Cast and crew'].map(lambda x : screenplaying(x))
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 264    1
# 265    1
# 266    1
# 267    1
# 268    1
# Name: Cast and crew, Length: 269, dtype: int64

# %%
df['Cast and crew'][1].split("(screenplay);")
# Out:
# ['Lauren Wolkstein (director); Christopher Radcliff (co-director/screenplay); Alex Pettyfer, James Freedson-Jackson, Emily Althaus, Gene Jones, Owen Campbell, Tobias Campbell']

# %%
def get_actor(x,num):
    try:
        if "(screenplay); " in x:
            return ((x.split("screenplay); ")[-1]).split(", ")[num])
        elif "(co-director/screenplay);" in x:
            return ((x.split("co-director/screenplay); ")[-1]).split(", ")[num])
        elif "(director/screenplay);" in x:
            return ((x.split("director/screenplay); ")[-1]).split(", ")[num])
    except:
        return np.nan

# %%
df['actor_1_name'] = df['Cast and crew'].map(lambda x: get_actor(x,0))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['actor_2_name'] = df['Cast and crew'].map(lambda x: get_actor(x,1))
# Out:
# C:\Users\hp\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df['actor_3_name'] = df['Cast and crew'].map(lambda x: get_actor(x,2))

# %%
df.Title = df.Title.str.lower()

# %%
df.head()
# Out:
#                      Title                                      Cast and crew  \
# 0  insidious: the last key  Adam Robitel (director); Leigh Whannell (scree...
# 1         the strange ones  Lauren Wolkstein (director); Christopher Radcl...
# 2                 stratton  Simon West (director); Duncan Falconer, Warren...
# 3            sweet country  Warwick Thornton (director); David Tranter, St...
# 4             the commuter  Jaume Collet-Serra (director); Byron Willinger...
#
#                     genres       director_name    actor_1_name  \
# 0  Horror Mystery Thriller        Adam Robitel       Lin Shaye
# 1           Thriller Drama    Lauren Wolkstein   Alex Pettyfer
# 2          Action Thriller          Simon West  Dominic Cooper
# 3    Drama History Western    Warwick Thornton     Bryan Brown
# 4          Action Thriller  Jaume Collet-Serra     Liam Neeson
#
#              actor_2_name    actor_3_name
# 0           Angus Sampson  Leigh Whannell
# ...

# %%
df = df.drop(['Cast and crew'], axis = 1)

# %%
df = df.rename(columns={"Title" : "movie_title"})

# %%
df['actor_2_name'] = df['actor_2_name'].replace(np.nan, 'unknown')
df['actor_3_name'] = df['actor_3_name'].replace(np.nan, 'unknown')
df['actor_1_name'] = df['actor_1_name'].replace(np.nan, 'unknown')
df['genres'] = df['genres'].replace(np.nan,'unknown')

# %%
df.isna().sum()
# Out:
# movie_title      0
# genres           0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# dtype: int64

# %%
df['comb'] = df['actor_1_name'] + ' ' + df['actor_2_name'] + ' '+ df['actor_3_name'] + ' '+ df['director_name'] +' ' + df['genres']

# %%
df.head()
# Out:
#                movie_title                   genres       director_name  \
# 0  insidious: the last key  Horror Mystery Thriller        Adam Robitel
# 1         the strange ones           Thriller Drama    Lauren Wolkstein
# 2                 stratton          Action Thriller          Simon West
# 3            sweet country    Drama History Western    Warwick Thornton
# 4             the commuter          Action Thriller  Jaume Collet-Serra
#
#      actor_1_name            actor_2_name    actor_3_name  \
# 0       Lin Shaye           Angus Sampson  Leigh Whannell
# 1   Alex Pettyfer  James Freedson-Jackson   Emily Althaus
# 2  Dominic Cooper          Austin Stowell      Gemma Chan
# 3     Bryan Brown               Sam Neill         unknown
# 4     Liam Neeson            Vera Farmiga  Patrick Wilson
#
#                                                 comb
# 0  Lin Shaye Angus Sampson Leigh Whannell Adam Ro...
# 1  Alex Pettyfer James Freedson-Jackson Emily Alt...
# ...

# %%
d17 = pd.read_csv("Data2017.csv")
d17.head()
# Out:
#    Unnamed: 0      director_name     actor_1_name      actor_2_name  \
# 0           0      James Cameron      CCH Pounder  Joel David Moore
# 1           1     Gore Verbinski      Johnny Depp     Orlando Bloom
# 2           2         Sam Mendes  Christoph Waltz      Rory Kinnear
# 3           3  Christopher Nolan        Tom Hardy    Christian Bale
# 4           4        Doug Walker      Doug Walker        Rob Walker
#
#            actor_3_name                                        movie_title  \
# 0             Wes Studi                                             avatar
# 1        Jack Davenport           pirates of the caribbean: at world's end
# 2      Stephanie Sigman                                            spectre
# 3  Joseph Gordon-Levitt                              the dark knight rises
# 4                unknow  star wars: episode vii - the force awakens    ...
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# ...

# %%
d17 = d17.iloc[:,0:]
d17.head()
# Out:
#    Unnamed: 0      director_name     actor_1_name      actor_2_name  \
# 0           0      James Cameron      CCH Pounder  Joel David Moore
# 1           1     Gore Verbinski      Johnny Depp     Orlando Bloom
# 2           2         Sam Mendes  Christoph Waltz      Rory Kinnear
# 3           3  Christopher Nolan        Tom Hardy    Christian Bale
# 4           4        Doug Walker      Doug Walker        Rob Walker
#
#            actor_3_name                                        movie_title  \
# 0             Wes Studi                                             avatar
# 1        Jack Davenport           pirates of the caribbean: at world's end
# 2      Stephanie Sigman                                            spectre
# 3  Joseph Gordon-Levitt                              the dark knight rises
# 4                unknow  star wars: episode vii - the force awakens    ...
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# ...

# %%
d17['comb'] = d17['actor_1_name'] + ' ' + d17['actor_2_name'] + ' '+ d17['actor_3_name'] + ' '+ d17['director_name'] +' ' + d17['genres']

# %%
d17.head()
# Out:
#    Unnamed: 0      director_name     actor_1_name      actor_2_name  \
# 0           0      James Cameron      CCH Pounder  Joel David Moore
# 1           1     Gore Verbinski      Johnny Depp     Orlando Bloom
# 2           2         Sam Mendes  Christoph Waltz      Rory Kinnear
# 3           3  Christopher Nolan        Tom Hardy    Christian Bale
# 4           4        Doug Walker      Doug Walker        Rob Walker
#
#            actor_3_name                                        movie_title  \
# 0             Wes Studi                                             avatar
# 1        Jack Davenport           pirates of the caribbean: at world's end
# 2      Stephanie Sigman                                            spectre
# 3  Joseph Gordon-Levitt                              the dark knight rises
# 4                unknow  star wars: episode vii - the force awakens    ...
#
#                             genres  \
# 0  Action Adventure Fantasy Sci-Fi
# ...

# %%
data18 = d17.append(df,ignore_index=True,sort=False)

# %%
data18
# Out:
#       Unnamed: 0      director_name     actor_1_name      actor_2_name  \
# 0            0.0      James Cameron      CCH Pounder  Joel David Moore
# 1            1.0     Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            2.0         Sam Mendes  Christoph Waltz      Rory Kinnear
# 3            3.0  Christopher Nolan        Tom Hardy    Christian Bale
# 4            4.0        Doug Walker      Doug Walker        Rob Walker
# ...          ...                ...              ...               ...
# 5634         NaN         Etan Cohen     Will Ferrell    John C. Reilly
# 5635         NaN         Adam McKay   Christian Bale         Amy Adams
# 5636         NaN         Mimi Leder   Felicity Jones      Armie Hammer
# 5637         NaN       Karyn Kusama    Nicole Kidman    Sebastian Stan
# 5638         NaN        David Slade  Fionn Whitehead      Will Poulter
#
#               actor_3_name                                        movie_title  \
# ...

# %%
data18.columns
# Out:
# Index(['Unnamed: 0', 'director_name', 'actor_1_name', 'actor_2_name',
#        'actor_3_name', 'movie_title', 'genres', 'comb'],
#       dtype='object')

# %%
data18 = data18.drop(['Unnamed: 0'],axis=1)

# %%
data18
# Out:
#           director_name     actor_1_name      actor_2_name  \
# 0         James Cameron      CCH Pounder  Joel David Moore
# 1        Gore Verbinski      Johnny Depp     Orlando Bloom
# 2            Sam Mendes  Christoph Waltz      Rory Kinnear
# 3     Christopher Nolan        Tom Hardy    Christian Bale
# 4           Doug Walker      Doug Walker        Rob Walker
# ...                 ...              ...               ...
# 5634         Etan Cohen     Will Ferrell    John C. Reilly
# 5635         Adam McKay   Christian Bale         Amy Adams
# 5636         Mimi Leder   Felicity Jones      Armie Hammer
# 5637       Karyn Kusama    Nicole Kidman    Sebastian Stan
# 5638        David Slade  Fionn Whitehead      Will Poulter
#
#               actor_3_name                                        movie_title  \
# 0                Wes Studi                                             avatar
# 1           Jack Davenport           pirates of the caribbean: at world's end
# ...
